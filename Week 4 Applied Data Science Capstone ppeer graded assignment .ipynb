# %% [markdown]
# Capstone Project - The Battle of Neighborhoods
#
# Import Libraries

# %% [markdown]
# Data :
# One city will be analysed in this project :Foodbox in New york City.
#
# We will be using the below datasets for analysing Newyork city
#
# Data 1 : Neighborhood has a total of 5 boroughs and 306 neighborhoods. In order to segement the neighborhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood.
#
# This dataset exists for free on the web. Link to the dataset is : https://geo.nyu.edu/catalog/nyu_2451_34572

# %% [markdown]
# Data 2 : Second data which will be used is the DOHMH Farmers Markets and Food Boxes dataset. In this we will be using the data of Farmers Markets.
#
# https://data.cityofnewyork.us/dataset/DOHMH-Farmers-Markets-and-Food-Boxes/8vwk-6iz2
#
# Website-https://www.grownyc.org/greenmarketco/foodbox
# GrowNYC's Fresh Food Box Program is a food access initiative that enables under-served communities to purchase fresh, healthy, and primarily regionally grown produce well below traditional retail prices.
#
# A farmers' market is often defined as a public site used by two or more local or regional producers for the direct sale of farm products to consumers. In addition to fresh fruits and vegetables, markets may sell dairy products, fish, meat, baked goods, and other minimally processed foods.

# %% [markdown]
# Data 3 : For the below analysis we will get data from wikipedia as given below :
#
# New York Population
# New York City Demographics
# Cuisine of New York city
# https://en.wikipedia.org/wiki/New_York_City
# https://en.wikipedia.org/wiki/Economy_of_New_York_City
# https://en.wikipedia.org/wiki/Portal:New_York_City
# https://en.wikipedia.org/wiki/Cuisine_of_New_York_City
# https://en.wikipedia.org/wiki/List_of_Michelin_starred_restaurants_in_New_York_City

# %% [markdown]
# Data 4 : Newyork city geographical coordinates data will be utilized as input for the Foursquare API, that will be leveraged to provision venues information for each neighborhood.We will use the Foursquare API to explore neighborhoods in New York City. The below is image of the Foursquare API data.

# %%
import requests
import pandas as pd
import numpy as np

# !pip install geopy
from geopy.geocoders import Nominatim 

from IPython.display import Image
from IPython.core.display import HTML

from pandas.io.json import json_normalize

# !pip install folium
import folium

print('Folium installed!')
# Out:
# Requirement already satisfied: geopy in c:\programdata\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\programdata\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.14.0)
# Folium installed!

# %%
CLIENT_ID = 'VW4IYSJWZOV5MEUTYKEWPEINY3TZWYE0GJHVKNUQUSJ5DVFW'
CLIENT_SECRET = 'NORPTKWY0S0MX3LH53PPQPJ410DHEFFJMVU055BAKPE1QAH4'
VERSION = '20180604'
LIMIT = 30
print('Credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Credentails:
# CLIENT_ID: VW4IYSJWZOV5MEUTYKEWPEINY3TZWYE0GJHVKNUQUSJ5DVFW
# CLIENT_SECRET:NORPTKWY0S0MX3LH53PPQPJ410DHEFFJMVU055BAKPE1QAH4

# %% [markdown]
# I'm at The Chelsea Hotel and would like to find good restaurants that are close by. I'll start by getting the Hotel's address.

# %%
address = '222 W 23rd St, New York, NY 10011'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7443742 -73.9968175

# %% [markdown]
# Let's pretend it's lunch time and I am craving Italian food. I will need to query to search for Italian food that is within 500 meters from the Chelsea Hotel.

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=VW4IYSJWZOV5MEUTYKEWPEINY3TZWYE0GJHVKNUQUSJ5DVFW&client_secret=NORPTKWY0S0MX3LH53PPQPJ410DHEFFJMVU055BAKPE1QAH4&ll=40.7443742,-73.9968175&v=20180604&query=Italian&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9d61e0c546f3001bf943f9'},
#  'response': {'venues': [{'id': '5c893ef0d8096e0039e7363b',
#     'name': 'Pisillo Italian Panini',
#     'location': {'address': '124 W 25th St',
#      'crossStreet': 'btwn 6th & 7th Ave',
#      'lat': 40.744566,
#      'lng': -73.992868,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744566,
#        'lng': -73.992868},
#       {'label': 'entrance', 'lat': 40.744568, 'lng': -73.992984}],
#      'distance': 333,
#      'postalCode': '10001',
#      'cc': 'US',
#      'neighborhood': 'Chelsea',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['124 W 25th St (btwn 6th & 7th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1108715',
#      'url': 'https://www.seamless.com/menu/pisillo-124-w-25th-st-new-york/1108715?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1108715',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '4a85a9e7f964a520d3fe1fe3',
#     'name': 'Italian Ice Cart',
#     'location': {'address': 'W 18th St',
#      'crossStreet': '8th Ave',
#      'lat': 40.744268165756644,
#      'lng': -73.9980991642575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744268165756644,
#        'lng': -73.9980991642575}],
#      'distance': 108,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['W 18th St (8th Ave)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '59cbe33b50a6f0209c7b52c4',
#     'name': 'Claudio Italian Restaurant',
#     'location': {'address': '344 8th Ave',
#      'crossStreet': '26th & 27th  Sts',
#      'lat': 40.747358,
#      'lng': -73.996907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747358,
#        'lng': -73.996907}],
#      'distance': 332,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['344 8th Ave (26th & 27th  Sts)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1229971',
#      'url': 'https://www.seamless.com/menu/claudios-pizzeria-334-8th-ave-new-york/1229971?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1229971',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '5014183ce4b0073bd04161fa',
#     'name': 'Old Fashioned Hand Made Italian Ice',
#     'location': {'lat': 40.74356804811844,
#      'lng': -73.99170041320215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74356804811844,
#        'lng': -73.99170041320215}],
#      'distance': 440,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10023', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '50393bd2e4b0014516101a0e',
#     'name': 'Maffel Italian Eatery',
#     'location': {'lat': 40.741749,
#      'lng': -73.992574,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.741749,
#        'lng': -73.992574}],
#      'distance': 462,
#      'postalCode': '10010',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10010', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '526324c111d238e68dea4efd',
#     'name': 'Tre Stelle Italian Restaurant&Bar',
#     'location': {'address': '39 west 24 th street',
#      'crossStreet': 'tra la 5th e la 6th avenue',
#      'lat': 40.743426782849795,
#      'lng': -73.99104481265644,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.743426782849795,
#        'lng': -73.99104481265644}],
#      'distance': 498,
#      'postalCode': '10010',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['39 west 24 th street (tra la 5th e la 6th avenue)',
#       'New York, NY 10010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '69667828'},
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '4b0af88cf964a520e22a23e3',
#     'name': 'La Cucina Italiana',
#     'location': {'address': '512 Fashion Ave',
#      'crossStreet': 'W 38th St',
#      'lat': 40.744667,
#      'lng': -74.000964,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744667,
#        'lng': -74.000964}],
#      'distance': 351,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['512 Fashion Ave (W 38th St)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '4af4b9adf964a52074f521e3',
#     'name': 'biricchino',
#     'location': {'address': '260 W 29th St',
#      'crossStreet': 'at 8th Ave.',
#      'lat': 40.74887439608574,
#      'lng': -73.9954686909914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74887439608574,
#        'lng': -73.9954686909914},
#       {'label': 'entrance', 'lat': 40.748867, 'lng': -73.995545}],
#      'distance': 513,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['260 W 29th St (at 8th Ave.)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '346976',
#      'url': 'https://www.seamless.com/menu/biricchino-260-w-29th-st-new-york/346976?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=346976',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '446832385'},
#     'referralId': 'v-1587372560',
#     'hasPerk': False},
#    {'id': '4a71be2bf964a52070d91fe3',
#     'name': 'Salumeria Biellese Delicatessen',
#     'location': {'address': '378 8th Ave',
#      'crossStreet': 'at W 29th St',
#      'lat': 40.749081321496135,
#      'lng': -73.9956062591867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.749081321496135,
#        'lng': -73.9956062591867},
#       {'label': 'entrance', 'lat': 40.748887, 'lng': -73.995663}],
#      'distance': 533,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['378 8th Ave (at W 29th St)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '340671',
#      'url': 'https://www.seamless.com/menu/salumeria-biellese-delicatessen-378-8th-ave-new-york/340671?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=340671',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1587372560',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
df = json_normalize(venues)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                                 name  \
# 0  5c893ef0d8096e0039e7363b               Pisillo Italian Panini
# 1  4a85a9e7f964a520d3fe1fe3                     Italian Ice Cart
# 2  59cbe33b50a6f0209c7b52c4           Claudio Italian Restaurant
# 3  5014183ce4b0073bd04161fa  Old Fashioned Hand Made Italian Ice
# 4  50393bd2e4b0014516101a0e                Maffel Italian Eatery
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...  v-1587372560    False
# 1  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1587372560    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1587372560    False
# 3  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1587372560    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1587372560    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0    124 W 25th St   btwn 6th & 7th Ave     40.744566    -73.992868
# 1        W 18th St              8th Ave     40.744268    -73.998099
# 2      344 8th Ave     26th & 27th  Sts     40.747358    -73.996907
# 3              NaN                  NaN     40.743568    -73.991700
# 4              NaN                  NaN     40.741749    -73.992574
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.744566, 'lng':...                333
# 1  [{'label': 'display', 'lat': 40.74426816575664...                108
# 2  [{'label': 'display', 'lat': 40.747358, 'lng':...                332
# 3  [{'label': 'display', 'lat': 40.74356804811844...                440
# 4  [{'label': 'display', 'lat': 40.741749, 'lng':...                462
#
#   location.postalCode location.cc location.neighborhood location.city  \
# 0               10001          US               Chelsea      New York
# 1               10011          US                   NaN      New York
# 2               10001          US                   NaN      New York
# 3               10023          US                   NaN      New York
# 4               10010          US                   NaN      New York
#
#   location.state location.country  \
# 0             NY    United States
# 1             NY    United States
# 2             NY    United States
# 3             NY    United States
# 4             NY    United States
#
#                            location.formattedAddress delivery.id  \
# 0  [124 W 25th St (btwn 6th & 7th Ave), New York,...     1108715
# 1  [W 18th St (8th Ave), New York, NY 10011, Unit...         NaN
# 2  [344 8th Ave (26th & 27th  Sts), New York, NY ...     1229971
# 3                [New York, NY 10023, United States]         NaN
# 4                [New York, NY 10010, United States]         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0  https://www.seamless.com/menu/pisillo-124-w-25...               seamless
# 1                                                NaN                    NaN
# 2  https://www.seamless.com/menu/claudios-pizzeri...               seamless
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                 delivery.provider.icon.name venuePage.id
# 0  /delivery_provider_seamless_20180129.png          NaN
# 1                                       NaN          NaN
# 2  /delivery_provider_seamless_20180129.png          NaN
# 3                                       NaN          NaN
# 4                                       NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
filtered_df = df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
filtered_df['categories'] = filtered_df.apply(get_category_type, axis=1)

# clean column names by keeping only last term
filtered_df.columns = [column.split('.')[-1] for column in filtered_df.columns]

filtered_df
# Out:
#                                   name          categories  \
# 0               Pisillo Italian Panini      Sandwich Place
# 1                     Italian Ice Cart          Food Truck
# 2           Claudio Italian Restaurant         Pizza Place
# 3  Old Fashioned Hand Made Italian Ice          Food Truck
# 4                Maffel Italian Eatery         Pizza Place
# 5    Tre Stelle Italian Restaurant&Bar  Italian Restaurant
# 6                   La Cucina Italiana  Italian Restaurant
# 7                           biricchino  Italian Restaurant
# 8      Salumeria Biellese Delicatessen       Deli / Bodega
#
#                 address                 crossStreet        lat        lng  \
# 0         124 W 25th St          btwn 6th & 7th Ave  40.744566 -73.992868
# 1             W 18th St                     8th Ave  40.744268 -73.998099
# 2           344 8th Ave            26th & 27th  Sts  40.747358 -73.996907
# 3                   NaN                         NaN  40.743568 -73.991700
# 4                   NaN                         NaN  40.741749 -73.992574
# 5  39 west 24 th street  tra la 5th e la 6th avenue  40.743427 -73.991045
# 6       512 Fashion Ave                   W 38th St  40.744667 -74.000964
# 7         260 W 29th St                 at 8th Ave.  40.748874 -73.995469
# 8           378 8th Ave                at W 29th St  40.749081 -73.995606
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.744566, 'lng':...       333      10001  US
# 1  [{'label': 'display', 'lat': 40.74426816575664...       108      10011  US
# 2  [{'label': 'display', 'lat': 40.747358, 'lng':...       332      10001  US
# 3  [{'label': 'display', 'lat': 40.74356804811844...       440      10023  US
# 4  [{'label': 'display', 'lat': 40.741749, 'lng':...       462      10010  US
# 5  [{'label': 'display', 'lat': 40.74342678284979...       498      10010  US
# 6  [{'label': 'display', 'lat': 40.744667, 'lng':...       351      10018  US
# 7  [{'label': 'display', 'lat': 40.74887439608574...       513      10001  US
# 8  [{'label': 'display', 'lat': 40.74908132149613...       533      10001  US
#
#   neighborhood      city state        country  \
# 0      Chelsea  New York    NY  United States
# 1          NaN  New York    NY  United States
# 2          NaN  New York    NY  United States
# 3          NaN  New York    NY  United States
# 4          NaN  New York    NY  United States
# 5          NaN  New York    NY  United States
# 6          NaN  New York    NY  United States
# 7          NaN  New York    NY  United States
# 8          NaN  New York    NY  United States
#
#                                     formattedAddress                        id
# 0  [124 W 25th St (btwn 6th & 7th Ave), New York,...  5c893ef0d8096e0039e7363b
# 1  [W 18th St (8th Ave), New York, NY 10011, Unit...  4a85a9e7f964a520d3fe1fe3
# 2  [344 8th Ave (26th & 27th  Sts), New York, NY ...  59cbe33b50a6f0209c7b52c4
# 3                [New York, NY 10023, United States]  5014183ce4b0073bd04161fa
# 4                [New York, NY 10010, United States]  50393bd2e4b0014516101a0e
# 5  [39 west 24 th street (tra la 5th e la 6th ave...  526324c111d238e68dea4efd
# 6  [512 Fashion Ave (W 38th St), New York, NY 100...  4b0af88cf964a520e22a23e3
# 7  [260 W 29th St (at 8th Ave.), New York, NY 100...  4af4b9adf964a52074f521e3
# 8  [378 8th Ave (at W 29th St), New York, NY 1000...  4a71be2bf964a52070d91fe3

# %%
filtered_df.name
# Out:
# 0                 Pisillo Italian Panini
# 1                       Italian Ice Cart
# 2             Claudio Italian Restaurant
# 3    Old Fashioned Hand Made Italian Ice
# 4                  Maffel Italian Eatery
# 5      Tre Stelle Italian Restaurant&Bar
# 6                     La Cucina Italiana
# 7                             biricchino
# 8        Salumeria Biellese Delicatessen
# Name: name, dtype: object
